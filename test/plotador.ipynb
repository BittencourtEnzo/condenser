# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3797, 4741, 5382,7332, 17337])
ypoints1 = np.array([124,114, 152,190,877])
ypoints2 = np.array([22,29, 28, 44, 250])
ypoints3 = np.array([81,78, 103, 116, 595])
ypoints4 = np.array([161, 150, 236, 230,1009 ])
ypoints5 = np.array([0.0093, 0.0107, 0.013, 0.0165, 0.0411])
ypoints6 = np.array([0.046,0.0479, 0.049, 0.0581,0.0697 ])

fig1 = plt.figure(1)
plt.plot(xpoints, ypoints1, marker = 'o')
plt.xlabel('Caracteres')  # Label for the x-axis
plt.ylabel('Tempo [s]')
fig1.show()

# %%
plt.figure(2)
plt.plot(xpoints, ypoints2, marker = 'o')
plt.xlabel('Caracteres')  # Label for the x-axis
plt.ylabel('Tempo [s]')
plt.show()

# %%
plt.figure(3)
plt.plot(xpoints, ypoints3, marker = 'o')
plt.xlabel('Caracteres')  # Label for the x-axis
plt.ylabel('Tempo [s]')
plt.show()

# %%
plt.figure(4)
plt.plot(xpoints, ypoints4, marker = 'o')
plt.xlabel('Caracteres')  # Label for the x-axis
plt.ylabel('Tempo [s]')
plt.show()

# %%
plt.figure(5)
plt.plot(xpoints, ypoints5, marker = 'o')
plt.xlabel('Caracteres')  # Label for the x-axis
plt.ylabel('Tempo [s]')
plt.show()

# %%
plt.figure(6)
plt.plot(xpoints, ypoints6, marker = 'o')
plt.xlabel('Caracteres')  # Label for the x-axis
plt.ylabel('Tempo [s]')
plt.show()
